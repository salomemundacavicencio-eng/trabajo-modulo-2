# %% [markdown]
# <a href="https://colab.research.google.com/github/salomemundacavicencio-eng/trabajo-modulo-2/blob/main/gestor_contactos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from contacto import Contacto

class GestorContactos:
    def __init__(self):
        self.contactos = []

    def agregar_contacto(self, contacto):
        self.contactos.append(contacto)

    def buscar_contacto(self, dato):
        for contacto in self.contactos:
            if contacto.nombre == dato or contacto.telefono == dato:
                return contacto
        return None

    def eliminar_contacto(self, dato):
        contacto = self.buscar_contacto(dato)
        if contacto:
            self.contactos.remove(contacto)
            return True
        return False
